# %%
#Lists - Variable with more than one value

# %%
which_one = int(input('Please input month (1 to 12)?'))

months = [ 'Jan','Feb', 'Mar', 'April', 'May', 'June', 
          'July', 'August', 'September', 'October', 'November', 'December']

#name of the list ==> months

if 1<= which_one <= 12:
    print('The month is', months[which_one - 1])
# Out:
# Please input month (1 to 12)?6
# The month is June

# %%
which_one = int(input('Please input month (1 to 12)?  ' ))

months = [ 'Jan','Feb', 'Mar', 'April', 'May', 'June', 
          'July', 'August', 'September', 'October', 'November', 'December']

#name of the list ==> months

if 1<= which_one <= 12:
    print('The month is', months[which_one - 1])
else:
    print('Input correct numerical')
    
#index start from 0
#index in motnhs = 0 to 11
# jan = 0, dec = 11
# Out:
# Please input month (1 to 12)?90
# Input correct numerical

# %%
demolist = ["life", 42, "the universe", 6 ,"and", 9]
print("demolist = ", demolist)
demolist.append("everthing")

print("After 'everthing' was appended demolist is now: ")
print(demolist)

print("len(demolist) =" , len (demolist))
print("demolist . index(42) = ", demolist.index(42))
print("demolist[1] = ", demolist[1])

print()
#Next we will loop through the list
for c in range(len(demolist)):
    print("demolist[", c,"] =", demolist[c])
    
del demolist[2] #del ==> delete

print("After 'the universe' was removed demolist is now:  ")
print(demolist)

if "life" in demolist:
    print(" 'life' was found in demolist")
else:
    print(" 'life' was not found in demolist")
    
if "amoeba" in demolist:
    print(" 'amoeba' was found in demolist")
    
if "amoeba" not in demolist:
    print(" 'amoeba' was not found in demolist")
    
    
print()
another_list = [ 42, 7 , 0 , 123 ]
another_list.sort()
print("The sorted another_list is", another_list)
# Out:
# demolist =  ['life', 42, 'the universe', 6, 'and', 9]
# After 'everthing' was appended demolist is now:
# ['life', 42, 'the universe', 6, 'and', 9, 'everthing']
# len(demolist) = 7
# demolist . index(42) =  1
# demolist[1] =  42
#
# demolist[ 0 ] = life
# demolist[ 1 ] = 42
# demolist[ 2 ] = the universe
# demolist[ 3 ] = 6
# demolist[ 4 ] = and
# demolist[ 5 ] = 9
# demolist[ 6 ] = everthing
# After 'the universe' was removed demolist is now:
# ['life', 42, 6, 'and', 9, 'everthing']
#  'life' was found in demolist
#  'amoeba' was not found in demolist
#
# The sorted another_list is [0, 7, 42, 123]

# %%
#different methods for list

#demolist[2]         => assess the element at index 2

#demolist[2] = 3     =>changes the element at index 2 to value 3

#del demolist[2]     =>deletes the element at index 2

#len(demolist)       =>returns the length of string

#"value" in demolist    => true if "value" is an element in demolist

#"value" not in demolist => true if "value" is not an element in demolist

#another_list.sort()   => sort to ascending, must be all numbers or all strings

#demolist.index("value")  => returns the index of first place where "value" is

#demolist.append("value") => adds element "value" at the end of list

#demolist.remove("value") => remove "value" in the list

# %%
menu_item = 0 #assign a value
namelist = [] #this is a blank list

while menu_item != 9:
    print('--------------------------')
    print("1. Print the list")               #print
    print("2. Add a name to the list")       #append
    print("3. Remove a name from the list")  #del or remove
    print("4. Change an item in the list")   #assign index to new imput
    print("9. Quit")
    
    menu_item = int(input("Pick an item from the menu:  "))
    
    if menu_item == 1:
        current = 0
        if len(namelist) > 0:
            while current < len(namelist):
                print(current, " . " , namelist[current])
                current = current + 1
        else:
            print("List is empty")
            
    elif menu_item == 2:
        name = input ("Type in a name to add:  ")
        namelist. append(name)
    
    elif menu_item == 3:
        del_name = input( 'What name would like like to delete? ')
        if del_name in namelist:
            #namelist.remove(del_name) also same function
            item_number = namelist.index(del_name) #find out what index it is
            del namelist[item_number]
            # The code removes the 1st occurance of the name
            # The code from Gerald removea all
            # while del name in namelist:
                    # item_number = namelist.index(del_name) 
                    # del namelist[item_number]
        else:
            print(del_name, "was not found")
    
    elif menu_item == 4:
        old_name = input("What name would you like to change")
        if old_name in namelist:
            item_number = namelist.index(old_name)
            new_name = input("What is the new name: ")
            namelist[item_number] = new_name
        else:
            print(old_name, "was not found")
            
print("Goodbye")
# Out:
# --------------------------
# 1. Print the list
# 2. Add a name to the list
# 3. Remove a name from the list
# 4. Change an item in the list
# 9. Quit
# Pick an item from the menu:  2
# Type in a name to add:  jack
# --------------------------
# 1. Print the list
# 2. Add a name to the list
# 3. Remove a name from the list
# 4. Change an item in the list
# 9. Quit
# Pick an item from the menu:  2
# Type in a name to add:  jill
# --------------------------
# 1. Print the list
# 2. Add a name to the list
# 3. Remove a name from the list
# 4. Change an item in the list
# 9. Quit
# Pick an item from the menu:  1
# 0  .  jack
# 1  .  jill
# --------------------------
# 1. Print the list
# 2. Add a name to the list
# 3. Remove a name from the list
# 4. Change an item in the list
# 9. Quit
# Pick an item from the menu:  3
# What name would like like to delete? jack
# --------------------------
# 1. Print the list
# 2. Add a name to the list
# 3. Remove a name from the list
# ...

# %%
#This program runs a test of knowledge

#first get the test questions
#later this will be modified to use file io.

def get_questions():
    #notice how the data is stored as a list of lists
    return [ ["what color is the daytime sky on a clear day" , "blue"]
             ["what is the answer to life, the universe and everything?", "42"]
             ["what is a three letter word for mouse trap?" , "cat"]]
    
# this will test a single question
#it takes a single question in
#it returns Truw if user typed the correct answer, otherwise False
            
def check_question(question_and_answer) :
            #extract the question and the answer from the list
            #this function takes a list with 2 elements, a qn and ans
            question = qn_and_ans[0]
            answer   = qn_and_ans[1]
            # give question to the user
            given_answer = input(question)
            #compare the user's answer to the tester's answer
            if answer == given_answer:
                print('Correct')
                return True
            else:
                print("Incorrect, correct was:", answer)
                return False
            
#this will run through all the questions
def run_tes(questions):
            if len(questions) == 0:
                print("No questions were given.")
                # the return exits the function
                return
            index = 0
            right = 0
            while index < len(questions):
                #check the question
                #note this is extracting a question and answer from list
                if check_question(question[index]):
# Out:
#   File "<ipython-input-8-03501ff5fa72>", line 44
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
#This program runs a test of knowledge

#first get the test questions
#later this will be modified to use file io.

def get_questions():
    #notice how the data is stored as a list of lists
    return [ ["what color is the daytime sky on a clear day" , "blue"],
             ["what is the answer to life, the universe and everything?", "42"],
             ["what is a three letter word for mouse trap?" , "cat"]]

# %%
# this will test a single question
#it takes a single question in
#it returns Truw if user typed the correct answer, otherwise False
            
def check_question(qn_and_ans):
            #extract the question and the answer from the list
            #this function takes a list with 2 elements, a qn and ans
            question = qn_and_ans[0]
            answer   = qn_and_ans[1]
            # give question to the user
            given_answer = input(question)
            #compare the user's answer to the tester's answer
            if answer == given_answer:
                print('Correct')
                return True
            else:
                print("Incorrect, correct was:", answer)
                return False

# %%
#this will run through all the questions

def run_test(questions):
    if len(questions) == 0:
        print('No questions were given')
        #the return exists the function
        return
    index = 0
    right = 0
    while index < len(questions[index]):
        if check_question(questions[index]):
            right = right + 1
            #go to the next qn
        index = index + 1
    #notice the order of the computation, first multiply then divide
    print("you got", right* 100/len(questions), \
         "% right out of", len(questions))

run_test(get_questions())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b8564bde437d> in <module>
#      17          "% right out of", len(questions))
#      18
# ---> 19 run_test(get_questions())
#
# NameError: name 'get_questions' is not defined

# %%
#This program runs a test of knowledge

#first get the test questions
#later this will be modified to use file io.

def get_questions():
    #notice how the data is stored as a list of lists
    return [ ["what color is the daytime sky on a clear day" , "blue"],
             ["what is the answer to life, the universe and everything?", "42"],
             ["what is a three letter word for mouse trap?" , "cat"]]

# this will test a single question
#it takes a single question in
#it returns Truw if user typed the correct answer, otherwise False
            
def check_question(qn_and_ans):
            #extract the question and the answer from the list
            #this function takes a list with 2 elements, a qn and ans
            question = qn_and_ans[0]
            answer   = qn_and_ans[1]
            # give question to the user
            given_answer = input(question)
            #compare the user's answer to the tester's answer
            if answer == given_answer:
                print('Correct')
                return True
            else:
                print("Incorrect, correct was:", answer)
                return False
            
#this will run through all the questions

def run_test(questions):
    if len(questions) == 0:
        print('No questions were given')
        #the return exists the function
        return
    index = 0
    right = 0
    while index < len(questions[index]):
        if check_question(questions[index]):
            right = right + 1
            #go to the next qn
        index = index + 1
    #notice the order of the computation, first multiply then divide
    print("you got", right* 100/len(questions), \
         "% right out of", len(questions))

run_test(get_questions())
# Out:
# what color is the daytime sky on a clear dayblue
# Correct
# what is the answer to life, the universe and everything?8
# Incorrect, correct was: 42
# you got 33.333333333333336 % right out of 3

# %%
#showing a list of questions and answers
def showquestions():
    q = 0
    while q < len(questions):
        a = 0
        print("Q: ", questions[q][a])
        a = 1
        print("A: ", questions[q][a])
        q = q + 1
        
#define the menu function
def menu():
    print("----------------")
    print("Menu:   ")
    print("1 - Take the test")
    print("2 - View a list of questions and answers")
    print("3 - View the menu")
    print("5 - Quit")
    print("----------------") 
    
choice = "3"
while choice != "5":
    if choice == "1":
        run_test(questions)
    elif choice == "2":
        showquestions()
    elif choice == "3":
        menu()
    print()
    choice = input ("Choose your option from the menu above: ")
# Out:
# ----------------
# Menu:
# 1 - Take the test
# 2 - View a list of questions and answers
# 3 - View the menu
# 5 - Quit
# ----------------

# %%
# this program runs a test of knowledge

questions = [ ["what color is the daytime sky on a clear day" , "blue"],
             ["what is the answer to life, the universe and everything?", "42"],
             ["what is a three letter word for mouse trap?" , "cat"],
             ["what noise does a truly advanced  machine make? ", "ping"]]

# this will test a single question
#it takes a single question in
#it returns True if the user type the correct answer:

def check_qn(qn_and_ans):
            #extract the question and the answer from the list
            #this function takes a list with 2 elements, a qn and ans
            question = qn_and_ans[0]
            answer   = qn_and_ans[1]
            # give question to the user
            given_answer = input(question)
            #compare the user's answer to the tester's answer
            if answer == given_answer:
                print('Correct')
                return True
            else:
                print("Incorrect, correct was:", answer)
                return False

def run_test(questions):
    
    if len(questions) == 0:
        print('No questions were given')
        #the return exists the function
        return
    index = 0
    right = 0
    while index < len(questions[index]):
        if check_question(questions[index]):
            right = right + 1
            #go to the next qn
        index = index + 1
    #notice the order of the computation, first multiply then divide
    print("you got", right* 100/len(questions), \
         "% right out of", len(questions))

#showing a list of questions and answers
def showquestions():
    q = 0
    while q < len(questions):
        a = 0
        print("Q: ", questions[q][a])
        a = 1
        print("A: ", questions[q][a])
        q = q + 1
        
#define the menu function
def menu():
    print("----------------")
    print("Menu:   ")
    print("1 - Take the test")
    print("2 - View a list of questions and answers")
    print("3 - View the menu")
    print("5 - Quit")
    print("----------------") 
    
choice = "3"
while choice != "5":
    if choice == "1":
        run_test(questions)
    elif choice == "2":
        showquestions()
    elif choice == "3":
        menu()
    print()
    choice = input ("Choose your option from the menu above: ")
